# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
X, y = fetch_openml("mnist_784", version=1, return_X_y=True)
X = X / 255.0
print(X.shape)
X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]
classifier = MLPClassifier(
    hidden_layer_sizes=(50, 20, 10),
    max_iter=100,
    alpha=1e-4,
    solver="sgd",
    verbose=10,
    random_state=1,
    learning_rate_init=0.1,
)
classifier.fit(X_train, y_train)
print("Training set score: %f" % classifier.score(X_train, y_train))
print("Test set score: %f" % classifier.score(X_test, y_test))
fig, axes = plt.subplots(1, 1)
axes.plot(classifier.loss_curve_, 'o-')
axes.set_xlabel("Number of iterations")
axes.set_ylabel("Loss")
plt.show()
len(classifier.intercepts_) == len(classifier.coefs_) == 4
target_layer = 0

fig, axes = plt.subplots(1, 1, figsize=(15, 6))
axes.imshow(np.transpose(classifier.coefs_[target_layer]), cmap=plt.get_cmap("gray"), aspect="auto")
axes.set_xlabel(f"Neurons in layer {target_layer}")
axes.set_ylabel("Neurons in output layer")
plt.show()
target_layer = 0
fig, axes = plt.subplots(4, 4)
vmin, vmax = classifier.coefs_[0].min(), classifier.coefs_[target_layer].max()
for coef, ax in zip(classifier.coefs_[0].T, axes.ravel()):
    ax.matshow(coef.reshape(28, 28), cmap=plt.cm.gray, vmin=0.5*vmin, vmax=0.5*vmax)
    ax.set_xticks(())
    ax.set_yticks(())
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (70000, 784)
# Iteration 1, loss = 0.42635367
# Iteration 2, loss = 0.15133481
# Iteration 3, loss = 0.11926082
# Iteration 4, loss = 0.10128421
# Iteration 5, loss = 0.08698448
# Iteration 6, loss = 0.08018627
# Iteration 7, loss = 0.07544472
# Iteration 8, loss = 0.06650726
# Iteration 9, loss = 0.06502276
# Iteration 10, loss = 0.05670472
# Iteration 11, loss = 0.05228727
# Iteration 12, loss = 0.05194876
# Iteration 13, loss = 0.04580530
# Iteration 14, loss = 0.04507070
# Iteration 15, loss = 0.04141424
# Iteration 16, loss = 0.03988480
# Iteration 17, loss = 0.03980626
# Iteration 18, loss = 0.03593785
# Iteration 19, loss = 0.03619045
# Iteration 20, loss = 0.03170852
# Iteration 21, loss = 0.03625169
# Iteration 22, loss = 0.03089524
# Iteration 23, loss = 0.02850056
# Iteration 24, loss = 0.02590310
# Iteration 25, loss = 0.02983057
# Iteration 26, loss = 0.03076610
# Iteration 27, loss = 0.02797107
# Iteration 28, loss = 0.02725187
# Iteration 29, loss = 0.02635948
# Iteration 30, loss = 0.02273718
# Iteration 31, loss = 0.01989971
# Iteration 32, loss = 0.02792543
# Iteration 33, loss = 0.02547325
# Iteration 34, loss = 0.02221360
# Iteration 35, loss = 0.02130088
# Iteration 36, loss = 0.01986230
# Iteration 37, loss = 0.01820394
# Iteration 38, loss = 0.02267857
# Iteration 39, loss = 0.02109641
# Iteration 40, loss = 0.02207270
# Iteration 41, loss = 0.02007524
# Iteration 42, loss = 0.01859708
# Iteration 43, loss = 0.02481128
# Iteration 44, loss = 0.01715189
# Iteration 45, loss = 0.01974095
# Iteration 46, loss = 0.01674093
# Iteration 47, loss = 0.01480502
# Iteration 48, loss = 0.01717700
# Iteration 49, loss = 0.02046642
# Iteration 50, loss = 0.01769848
# Iteration 51, loss = 0.01602011
# Iteration 52, loss = 0.01775700
# Iteration 53, loss = 0.01663760
# Iteration 54, loss = 0.01229629
# Iteration 55, loss = 0.01769126
# Iteration 56, loss = 0.01563929
# Iteration 57, loss = 0.01589301
# Iteration 58, loss = 0.01269628
# Iteration 59, loss = 0.01052639
# Iteration 60, loss = 0.02301805
# Iteration 61, loss = 0.01424613
# Iteration 62, loss = 0.01272615
# Iteration 63, loss = 0.01505988
# Iteration 64, loss = 0.01590737
# Iteration 65, loss = 0.01622619
# Iteration 66, loss = 0.01507573
# Iteration 67, loss = 0.01563766
# Iteration 68, loss = 0.01364227
# Iteration 69, loss = 0.00785313
# Iteration 70, loss = 0.01297091
# Iteration 71, loss = 0.01159446
# Iteration 72, loss = 0.01214293
# Iteration 73, loss = 0.01697724
# Iteration 74, loss = 0.01659552
# Iteration 75, loss = 0.01366004
# Iteration 76, loss = 0.01226805
# Iteration 77, loss = 0.00991684
# Iteration 78, loss = 0.00968953
# Iteration 79, loss = 0.01671071
# Iteration 80, loss = 0.01579810
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training set score: 0.998200
# Test set score: 0.970600
